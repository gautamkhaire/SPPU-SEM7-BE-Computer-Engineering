# %% [markdown]
# # Assignment B4
# Implement Gradient Descent Algorithm to find the local minima of a function.<br>
# For example, find the local minima of the function y=(x+3)² starting from the point x=2.

# %% [markdown]
# ## Gradient Descent Algorithm

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def function(x):
    return (x+3)**2

# %%
def gradient_descent(starting_point, learning_rate, iterations):
    x_values = []
    y_values = []
    x = starting_point
    
    for i in range(iterations):
        gradient = 2*(x+3)
        x = x - learning_rate*gradient
        
        x_values.append(x)
        y_values.append(function(x))
        
        print("Iteration",i,"\n x value is: ",x)
    return x_values,y_values

# %%
starting_point = 2
learning_rate = 0.1
iterations = 10000

# %%
x_values, y_values = gradient_descent(starting_point, learning_rate, iterations)
# Out:
# Iteration 0
#  x value is:  1.0
# Iteration 1
#  x value is:  0.19999999999999996
# Iteration 2
#  x value is:  -0.44000000000000017
# Iteration 3
#  x value is:  -0.9520000000000001
# Iteration 4
#  x value is:  -1.3616000000000001
# Iteration 5
#  x value is:  -1.6892800000000001
# Iteration 6
#  x value is:  -1.951424
# Iteration 7
#  x value is:  -2.1611392
# Iteration 8
#  x value is:  -2.32891136
# Iteration 9
#  x value is:  -2.463129088
# Iteration 10
#  x value is:  -2.5705032704
# Iteration 11
#  x value is:  -2.6564026163200003
# Iteration 12
#  x value is:  -2.725122093056
# Iteration 13
#  x value is:  -2.7800976744448
# Iteration 14
#  x value is:  -2.82407813955584
# Iteration 15
#  x value is:  -2.8592625116446717
# Iteration 16
#  x value is:  -2.8874100093157375
# Iteration 17
#  x value is:  -2.90992800745259
# Iteration 18
#  x value is:  -2.927942405962072
# Iteration 19
#  x value is:  -2.9423539247696575
# Iteration 20
#  x value is:  -2.953883139815726
# ...

# %%
x_vals = np.linspace(-10, 4, 100)
y_vals = function(x_vals)

# %%
plt.plot(x_vals, y_vals, label='y = (x+3)^2')
plt.scatter(x_values, y_values, color='red', label='Gradient Descent Path')
plt.xlabel('x')
plt.ylabel('y', rotation=0)
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
# Thus, gradient descent algorithm has been implemented. The local minimum for  y=(x+3)² was found to be very close to -3 after 161 iterations.
